# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import pandas as pd

# %%
#Setup for Google Drive and Google Sheets API
#Need to create a service account in Google Cloud to get the JSON key: https://console.cloud.google.com/iam-admin/serviceaccounts
#Need to enable Google Sheets and Google Drive APIs for the JSON key to work

scope = ["https://spreadsheets.google.com/feeds",'https://www.googleapis.com/auth/spreadsheets',"https://www.googleapis.com/auth/drive.file","https://www.googleapis.com/auth/drive"]
creds = ServiceAccountCredentials.from_json_keyfile_name('willamete-valley-plant-list-b71c56838f40.json', scope)
client = gspread.authorize(creds)

# %% [markdown]
# Fruit Tree Page

# %%
#Load fruit tree data from Google Sheets

sheet = client.open("Willamette Valley Multifunctional Plant List").worksheet("Trees")
data = sheet.get_all_records()
df_fruit_trees = pd.DataFrame(data)

# %%
#Set dataframe parameters

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Set index for dataframe

df_fruit_trees.set_index("Botanical name", inplace=True)
df_fruit_trees.index.name = None

# %%
#| label: table-fruit-trees

df_fruit_trees.style.set_table_styles([
    {'selector': 'th', 'props': [('width', '100px')]},  # Adjust header column widths
    {'selector': 'td', 'props': [('width', '200px')]},  # Adjust data column widths
])
df_fruit_trees
# Out:
#                                Common name Class Type      Height      Width  \
# Malus spp.                           Apple    ST    D    5' - 50'   4' - 30'
# Pyrus communis                        Pear    ST    D    7' - 50'   6' - 25'
# Prunus spp.                           Plum    ST    D
# Pyrus spp.                      Asian Pear     T    D   15' - 30'
# Prunus persica                       Peach    ST    D   15' - 25'
# Diospyrus virginiana    American persimmon     T    D  15' - 25'   15' - 20'
# Diospyrus kaki          Japanese persimmon     T    D  15' - 25'   15' - 20'
# Prunus spp.                         Cherry
# Ficus carica                           Fig    ST    D
# Asimina triloba                     Pawpaw     T    D   10' - 40'  10' - 20'
# Cydonia oblonga                     Quince     S    D    8' - 15'   8' - 12'
# Cornus mas                Cornelian Cherry    ST    D    8' - 20'   6' - 15'
# Mespilus germanica                  Medlar    ST
# Sambucus caerulea          Blue elderberry    ST    D    6' - 20'   4' - 20'
# Malus fiscal?         West Coast Crabapple     T    D    8' - 40'
# Lycium Barbarum          Chinese Wolfberry     S    D    8' - 15'  10' - 20'
#
#                                  Sun/Shade       Soil Type   Propagation  \
# Malus spp.                        Full sun              CL         G/S/R
# Pyrus communis                    Full sun            C/CL           G/S
# Prunus spp.                       Full sun              CL         G/S/R
# Pyrus spp.                        Full sun              SL             G
# Prunus persica                    Full sun              CL           G/S
# Diospyrus virginiana              Full sun            C/CL           G/S
# Diospyrus kaki                    Full sun            C/CL             G
# Prunus spp.                       Full sun              CL         G/S/R
# Ficus carica                      Full sun           CL/SL         G/L/C
# Asimina triloba       Full sun/Partial sun  Many - WD best  Root Cutting
# Cydonia oblonga                   Full sun              CL         G/S/R
# Cornus mas            Full sun/Partial sun          Many             G/S
# Mespilus germanica                Full sun            C/CL           G/S
# Sambucus caerulea     Full sun/Partial sun        WD/SL/CL
# Malus fiscal?         Full sun/Partial sun            C/CL           S/C
# Lycium Barbarum       Full sun/Partial sun              WD            S
#
#                      Native Water requirement Maintenance Bloom time  \
# Malus spp.                                              R
# Pyrus communis                              F           R
# Prunus spp.
# Pyrus spp.                                              R
# Prunus persica                                          R
# Diospyrus virginiana                                   LN
# Diospyrus kaki                                        LNM
# Prunus spp.                                             M
# Ficus carica                                            M
# Asimina triloba                             R          LN
# Cydonia oblonga                                        LN
# Cornus mas                              R/SDT          LN
# Mespilus germanica                                      L
# Sambucus caerulea                       R/SDT         LNM
# Malus fiscal?                          R/F/DT         LNM
# Lycium Barbarum
#
#                      Fruit time Medicinal Nitrogen fixer Insect/Bee/Birds  \
# Malus spp.
# Pyrus communis
# Prunus spp.
# Pyrus spp.
# Prunus persica
# Diospyrus virginiana
# Diospyrus kaki
# Prunus spp.
# Ficus carica
# Asimina triloba
# Cydonia oblonga
# Cornus mas
# Mespilus germanica
# Sambucus caerulea
# Malus fiscal?
# Lycium Barbarum
#
#                      Other uses Rate of growth Flower color  \
# Malus spp.
# Pyrus communis
# Prunus spp.
# Pyrus spp.
# Prunus persica
# Diospyrus virginiana
# Diospyrus kaki
# Prunus spp.
# Ficus carica
# Asimina triloba
# Cydonia oblonga
# Cornus mas
# Mespilus germanica
# Sambucus caerulea
# Malus fiscal?
# Lycium Barbarum
#
#                      Fall or winter cover Pollinator habitat
# Malus spp.
# Pyrus communis
# Prunus spp.
# Pyrus spp.
# Prunus persica
# Diospyrus virginiana
# Diospyrus kaki
# Prunus spp.
# Ficus carica
# Asimina triloba
# Cydonia oblonga
# Cornus mas
# Mespilus germanica
# Sambucus caerulea
# Malus fiscal?
# Lycium Barbarum

# %%
#Load ground cover data from Google Sheets

sheet = client.open("Willamette Valley Multifunctional Plant List").worksheet("Ground Cover")
data = sheet.get_all_records()
df_ground_cover = pd.DataFrame(data)

# %%
#Set dataframe parameters

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', 3)
pd.set_option('display.max_rows', None)

# %%
# Set index for dataframe

df_ground_cover.set_index("Botanical name", inplace=True)
df_ground_cover.index.name = None

# %%
#| label: table-ground-cover

df_ground_cover
# Out:
#                                                      Common name Class  \
# Fragaria spp. (x ananassa & vesca?)  Strawberry                   GC
# Ceanothus Cuneatus                   Buckbrush                     S
# Arctostaphylos uva-ursi              Kinnikinnick                 GC
# Smilacina Racemosa - See A                                         P
# Tussilago Farfara                    Coltsfoot
# Montia perfoliata - See C            Miner’s Lettuce              AGC
# Teucrium                             Germander                    GC
# Satureja douglasii                   Yerba Buena                  GC
# Coptis Sp.                           Goldthread                   GC
# Baccharis Magellanica                                             GC
# Smilacina Stellata - See B           Starry False Solomon's Seal  GC
# Maianthemum Dilatatum                False Lily of the Valley     GC
# Peltiphyllum Peltatum                Umbrella Plant
# Petasites Frigibus - See D           Palmate Sweet Coltsfoot
#
#                                        Type     Height  \
# Fragaria spp. (x ananassa & vesca?)   E      3"
# Ceanothus Cuneatus                   EG      3' - 8'
# Arctostaphylos uva-ursi              EG      1" - 5"
# Smilacina Racemosa - See A            D      1' - 3'
# Tussilago Farfara
# Montia perfoliata - See C            RESEED  2" - 1'
# Teucrium                              E      2"
# Satureja douglasii                           1" - 2"
# Coptis Sp.                                   4"
# Baccharis Magellanica                        6"
# Smilacina Stellata - See B            D      10" - 12"
# Maianthemum Dilatatum                 N      6" - 15"
# Peltiphyllum Peltatum                 D      1' - 4'
# Petasites Frigibus - See D            D      6" - 4'
#
#                                                          Width Sun/Shade  \
# Fragaria spp. (x ananassa & vesca?)  6'
# Ceanothus Cuneatus
# Arctostaphylos uva-ursi              to 15'
# Smilacina Racemosa - See A           Spread
# Tussilago Farfara
# Montia perfoliata - See C            Spread
# Teucrium                             3'
# Satureja douglasii                   to 3'
# Coptis Sp.
# Baccharis Magellanica
# Smilacina Stellata - See B           Spread
# Maianthemum Dilatatum                Spread
# Peltiphyllum Peltatum                Spread by Rhizome
# Petasites Frigibus - See D           Creeping Rhizome Colonize
#
#                                        Soil Type Propagation Native  \
# Fragaria spp. (x ananassa & vesca?)  WD           Runner
# Ceanothus Cuneatus                   Very WD
# Arctostaphylos uva-ursi              Many
# Smilacina Racemosa - See A
# Tussilago Farfara
# Montia perfoliata - See C            Rich         Seed
# Teucrium                             CL           Division
# Satureja douglasii                   Many
# Coptis Sp.                           Forest Loam
# Baccharis Magellanica                Clay Loam
# Smilacina Stellata - See B
# Maianthemum Dilatatum
# Peltiphyllum Peltatum                Wet                       ?
# Petasites Frigibus - See D           Rich Moist
#
#                                     Water requirement Maintenance  Bloom time  \
# Fragaria spp. (x ananassa & vesca?)   R                LN          Spring
# Ceanothus Cuneatus                                                 Spring
# Arctostaphylos uva-ursi              R - DT            LN          Mar - June
# Smilacina Racemosa - See A           R-SDT             LN          Mar - July
# Tussilago Farfara
# Montia perfoliata - See C             R                LN          May - June
# Teucrium                              R                LN          June
# Satureja douglasii                   SDT-DT            LN          Apr - Sept
# Coptis Sp.
# Baccharis Magellanica                DT                ZIP
# Smilacina Stellata - See B           R-DT              LN          Mar - June
# Maianthemum Dilatatum                RW                LN          May - June
# Peltiphyllum Peltatum                RW                LN          Apr - July
# Petasites Frigibus - See D           RW                LN          Feb - June
#
#                                     Fruit time Medicinal Nitrogen fixer  \
# Fragaria spp. (x ananassa & vesca?)  Summer
# Ceanothus Cuneatus
# Arctostaphylos uva-ursi              Summer
# Smilacina Racemosa - See A           Aug.
# Tussilago Farfara
# Montia perfoliata - See C
# Teucrium
# Satureja douglasii
# Coptis Sp.
# Baccharis Magellanica                            ?
# Smilacina Stellata - See B           Aug.
# Maianthemum Dilatatum                Sept.
# Peltiphyllum Peltatum
# Petasites Frigibus - See D
#
#                                     Insect/Bee/Birds  \
# Fragaria spp. (x ananassa & vesca?)
# Ceanothus Cuneatus
# Arctostaphylos uva-ursi
# Smilacina Racemosa - See A
# Tussilago Farfara
# Montia perfoliata - See C
# Teucrium
# Satureja douglasii
# Coptis Sp.
# Baccharis Magellanica
# Smilacina Stellata - See B
# Maianthemum Dilatatum
# Peltiphyllum Peltatum
# Petasites Frigibus - See D
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Other uses  \
# Fragaria spp. (x ananassa & vesca?)
# Ceanothus Cuneatus                   Flowers for soap.  Leaves for tea.  Seeds edible.  Roots for red dye & medicine.
# Arctostaphylos uva-ursi              Best for highly maintained areas.  Can be overwhelmed by weeds.  Used for erosion control or for acidic low fertility areas
# Smilacina Racemosa - See A           Edible sweet fruit.  New shoots in salads.  Starchy roots cooked
# Tussilago Farfara
# Montia perfoliata - See C            Foliage fresh for salads.  Mild flavor.  Good texture.
# Teucrium
# Satureja douglasii                   Foliage makes a tasty aromatic tea.
# Coptis Sp.
# Baccharis Magellanica
# Smilacina Stellata - See B           Edible sweet fruit.  Tastes somewhat like raisins.
# Maianthemum Dilatatum                Edible sweet fruit.  Eat in moderation to avoid stomach ache.  Best combined with vegetable oil.
# Peltiphyllum Peltatum                Very young leaf stalks & flower stalks peeled & eaten fresh.  Loses flavor cooked.  Steam older stalks (bland & stringy) / reported from Benton County south.  More common S. Oregon Cascades mid to low altitudes.  Inhabits western Cascade stream banks sometimes even growing in fast moving stream.  Found in mixed forests & Ponderosa forests.  Great plumes of flowers followed by giant leaves 1' to 3' across.  Round leaves face up and resemble an umbrella.
# Petasites Frigibus - See D           Young leaves & possibly flower stalks contain a modest amount of Purrolizidine Alkaloids that cause permanent liver damage.  Mature leaves said to have almost none.  Roots (rhizomes) may have none of this alkaloid.  Indian Tribes (some) ate young leaves & flower heads.  Also, peeled young stalks cooked / rhizomes sometimes eaten if not used for medicine.  Important salt substitute for some tribes.  Leaves & stems are dried, burned & used as a seasoning rich in mineral salts.
#
#                                     Rate of growth Flower color  \
# Fragaria spp. (x ananassa & vesca?)
# Ceanothus Cuneatus
# Arctostaphylos uva-ursi              MF
# Smilacina Racemosa - See A            S
# Tussilago Farfara
# Montia perfoliata - See C             R
# Teucrium                              M
# Satureja douglasii                    S
# Coptis Sp.
# Baccharis Magellanica                 M             Excellent
# Smilacina Stellata - See B           MF
# Maianthemum Dilatatum                MF
# Peltiphyllum Peltatum
# Petasites Frigibus - See D            R
#
#                                     Fall or winter cover Pollinator habitat
# Fragaria spp. (x ananassa & vesca?)
# Ceanothus Cuneatus                   FCRMW
# Arctostaphylos uva-ursi              WPI
# Smilacina Racemosa - See A           WF
# Tussilago Farfara
# Montia perfoliata - See C             W
# Teucrium
# Satureja douglasii                    W
# Coptis Sp.                                                EG
# Baccharis Magellanica                 W                   EG
# Smilacina Stellata - See B           WF
# Maianthemum Dilatatum                WF
# Peltiphyllum Peltatum                W-PI-PU
# Petasites Frigibus - See D           FW-PI
